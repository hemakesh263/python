# %% [markdown]
# <a href="https://colab.research.google.com/github/hemakesh263/python/blob/main/Quiz_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Add Black color to the given list in the 4th place.
#
#  Rainbow = ['Red', 'Orange', 'Yellow', 'Green']

# %%
Rainbow=["Red","Orange","Yellow","Green"]
Rainbow.insert(3,"Black")
print(Rainbow)
# Out:
# ['Red', 'Orange', 'Yellow', 'Black', 'Green']

# %% [markdown]
# Find out the Largest of three numbers from the give input

# %%
a=5
b=3
c=2
if a>b and a>c:
    print("5")
elif b>c:
    print("3")
else:
    print("2")
# Out:
# 5

# %% [markdown]
# Write a program of swapping of two numbers

# %%
a=2
b=3
c=a
a=b
b=c
print("Result","=",a,b)
# Out:
# Result = 3 2

# %% [markdown]
# Find out the square root of the number

# %%
import math
a=4
b= 4 ** 0.5
print(b)
# Out:
# 2.0
